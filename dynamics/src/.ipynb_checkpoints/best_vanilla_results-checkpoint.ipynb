# %%
'''
This notebook depicts the results of a vanilla sequence model trained on (s,a) -> s' examples.
MACHINE: stronghold
MODEL ID: N/A
'''
# Out:
# "\nThis notebook depicts the results of a vanilla sequence model trained on (s,a) -> s' examples.\nMACHINE: stronghold\nMODEL ID: N/A\n"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import os
from vanilla_rnn import SequenceModel, Trainer
import torch
from utils.visualize import *
from utils.tools import *

# %%
root = os.getcwd()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset = root+"/../datasets/vanilla_rnn"
X_train, A_train, Y_train = np.load(dataset+"/train/states.npy"), np.load(dataset+"/train/actions.npy"), np.load(dataset+"/train/next_states.npy")
X_val, A_val, Y_val = np.load(dataset+"/val/states.npy"), np.load(dataset+"/val/actions.npy"), np.load(dataset+"/val/next_states.npy")
X_test, A_test, Y_test = np.load(dataset+"/test/states.npy"), np.load(dataset+"/test/actions.npy"), np.load(dataset+"/test/next_states.npy")

# X_train, Y_train = standardize_across_time(X_train), standardize_across_time(Y_train) 
# X_val, Y_val = standardize_across_time(X_val), standardize_across_time(Y_val) 
# X_test, Y_test = standardize_across_time(X_test), standardize_across_time(Y_test) 

X_train, Y_train = standardize_across_samples(X_train), standardize_across_samples(Y_train) 
X_val, Y_val = standardize_across_samples(X_val), standardize_across_samples(Y_val) 
X_test, Y_test = standardize_across_samples(X_test), standardize_across_samples(Y_test)

# %%
seq_model = SequenceModel(state_dim=21, action_dim=8, latent_dim=256, num_recurrent_layers=1, device=device).to(device)

# %%
trainer = Trainer(model=seq_model, device=device, learing_rate=1e-5)

# %%
# trainer.load_checkpoint(path=root+"/../models/vanilla_rnn.pth")

# %%
trainer.train(train=(X_train, A_train, Y_train), val=(X_val, A_val, Y_val), epochs=1000, batch_size=200, shuffle=True)
# Out:
# EPOCH 0 -- Train Loss: 0.57233  Validation Loss: 0.45155
# EPOCH 1 -- Train Loss: 0.40034  Validation Loss: 0.34561
# EPOCH 2 -- Train Loss: 0.31980  Validation Loss: 0.28470
# EPOCH 3 -- Train Loss: 0.27690  Validation Loss: 0.26562
# EPOCH 4 -- Train Loss: 0.25442  Validation Loss: 0.25850
# EPOCH 5 -- Train Loss: 0.24683  Validation Loss: 0.24589
# EPOCH 6 -- Train Loss: 0.23118  Validation Loss: 0.24033
# EPOCH 7 -- Train Loss: 0.22706  Validation Loss: 0.23233
# EPOCH 8 -- Train Loss: 0.21861  Validation Loss: 0.21778
# EPOCH 9 -- Train Loss: 0.20592  Validation Loss: 0.21585
# EPOCH 10 -- Train Loss: 0.20295  Validation Loss: 0.21575
# EPOCH 11 -- Train Loss: 0.20144  Validation Loss: 0.20765
# EPOCH 12 -- Train Loss: 0.19565  Validation Loss: 0.20242
# EPOCH 13 -- Train Loss: 0.19178  Validation Loss: 0.20045
# EPOCH 14 -- Train Loss: 0.19013  Validation Loss: 0.19499
# EPOCH 15 -- Train Loss: 0.18387  Validation Loss: 0.19431
# EPOCH 16 -- Train Loss: 0.18347  Validation Loss: 0.19406
# EPOCH 348 -- Train Loss: 0.08730  Validation Loss: 0.09252
# EPOCH 349 -- Train Loss: 0.08583  Validation Loss: 0.09123
# EPOCH 350 -- Train Loss: 0.08526  Validation Loss: 0.09087
# EPOCH 351 -- Train Loss: 0.08470  Validation Loss: 0.09098
# EPOCH 352 -- Train Loss: 0.08444  Validation Loss: 0.09015
# EPOCH 353 -- Train Loss: 0.08371  Validation Loss: 0.08951
# EPOCH 354 -- Train Loss: 0.08342  Validation Loss: 0.08952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6b27a61e8fbf> in <module>
# ----> 1 trainer.train(train=(X_train, A_train, Y_train), val=(X_val, A_val, Y_val), epochs=1000, batch_size=200, shuffle=True)
#
# ~/Dynamics-Model-Search/dynamics/src/vanilla_rnn.py in train(self, train, val, epochs, batch_size, shuffle)
#     146             self.train_epoch(train=(X_train, A_train, Y_train),
#     147                              val=(X_val, A_val, Y_val),
# --> 148                              epoch=epoch, batch_size=batch_size)
#     149
#     150     def save_checkpoint(self, path):
#
# ~/Dynamics-Model-Search/dynamics/src/vanilla_rnn.py in train_epoch(self, train, val, epoch, batch_size, verbose)
#     116             loss = self.model(X, A, Y)
#     117             batch_losses.append(loss)
# --> 118             loss.backward()
#     119             if verbose:
#     120                 print("LOSS: %.5f" % (loss))
#
# ~/.conda/envs/envPyTorch/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/.conda/envs/envPyTorch/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
trainer.save_checkpoint(path=root+"/../models/best_vanilla_rnn.pth")

# %%
X_train=torch.from_numpy(X_train[:]).to(device)
A_train=torch.from_numpy(A_train[:]).to(device)
Y_train=torch.from_numpy(Y_train[:]).to(device)

X_val=torch.from_numpy(X_val[:]).to(device)
A_val=torch.from_numpy(A_val[:]).to(device)
Y_val=torch.from_numpy(Y_val[:]).to(device)

X_test=torch.from_numpy(X_test[:]).to(device)
A_test=torch.from_numpy(A_test[:]).to(device)
Y_test=torch.from_numpy(Y_test[:]).to(device)

# %%
# PREDICTIONS

# %%
n = 5
t=1
Y_hat = seq_model.foresee(x=X_train[n:n+1].data.cpu().numpy(), a=A_train[n:n+1].data.cpu().numpy(), lookahead=t)

# %%
compare_states(Y=Y_train[n], Y_hat=Y_hat[0], overlap=True)            # animation of joints

# %%
# VELOCITIES
plot_velocity_curve(true=Y_train[n, :, 0].data.cpu().numpy(), pred=Y_hat[0, :, 0]) # x-velocity

# %%
plot_velocity_curve(true=Y_train[n, :, 1].data.cpu().numpy(), pred=Y_hat[0, :, 1]) # y-velocity

# %%
plot_velocity_curve(true=Y_train[n, :, 2].data.cpu().numpy(), pred=Y_hat[0, :, 2]) # z-velocity

# %%
# POSITIONS
plot_position_curve(true=compute_position_from_velocity(Y_train[n, :, 0].data.cpu().numpy()), pred=compute_position_from_velocity(Y_hat[0, :, 0])) # x-position

# %%
plot_position_curve(true=compute_position_from_velocity(Y_train[n, :, 1].data.cpu().numpy()), pred=compute_position_from_velocity(Y_hat[0, :, 1])) # y-position

# %%
plot_position_curve(true=compute_position_from_velocity(Y_train[n, :, 2].data.cpu().numpy()), pred=compute_position_from_velocity(Y_hat[0, :, 2])) # z-position
